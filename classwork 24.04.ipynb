# %%
s = '''гойда
... гойда
... гойда'''
print(s)

s = '\'гойда\' бубибу "бубибу" '
print(s)
# for i in s:
#     print(i)
# Out:
# гойда
# гойда
# гойда
# 'гойда' бубибу "бубибу"

# %%
s='abc'
c='abc'
id(s)
id(c)
print(id(s),
id(c))
# Out:
# 140730667707136 140730667707136

# %%
s = 'tsdft'
s = s.replace('ts', 'goida')
print(s)
# Out:
# goidadft

# %%
trans = str.maketrans('a', 'z', 'b')
string = 'aabbab'
print(string.translate(trans))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 trans = str.maketrans('a')
#       2 string = 'aabbab'
#       3 print(string.translate(trans))
#
# TypeError: if you give only one argument to maketrans it must be a dict

# %%
help(str.casefold)
# Out:
# Help on method_descriptor:
#
# casefold(self, /) unbound builtins.str method
#     Return a version of the string suitable for caseless comparisons.
