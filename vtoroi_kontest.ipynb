# %% [markdown]
# Задача A

# %%
a=input()
def func(a):
    stc=[]
    otk=['(','[','{']
    zak=[')',']','}']
    for i in range(len(a)):
        if a[i] in otk:
            stc.append(a[i])
            if i == len(a)-1:
                return 'No'
        else:
            if stc==[]:
                return 'No'
            else:
                if stc[-1]==otk[zak.index(a[i])]:
                    stc.pop()
                else: return 'No'
    return 'Yes'
print(func(a))
# Out:
# No

# %% [markdown]
# Задача B

# %%
n=int(input())
N=[list(map(int, input().split())) for i in range(n)]
def povt(N):
    return N[1]
N.sort(key=povt)
last = N[0][1]
ans = 1
for l, r in N:
    if l > last:
        ans += 1
        last = r
print(ans)
# Out:
# 1

# %% [markdown]
# Задача C

# %%
def mera(A):
    c=0
    n=len(A)
    for i in range(n-1):
        for j in range(i+1, n):
            if A[i] > A[j]: c+=1
    return c
def sortirovka():
    n, m = map(int, input().split())
    M=[input() for i in range(m)]
    M.sort(key=mera)
    for i in M:
        print(i)
K=int(input())
for i in range(K):
    sortirovka()
    print()
# Out:
# AACATGAAGG
# TTTTGGCCAA
# TTTGGCCAAA
# GATCAGATTT
# CCCGGGGGGA
# ATCGATGCAT

# %% [markdown]
# Задача D

# %%
n=int(input())
N=[list(map(int, input().split())) for i in range(n)]
def povt(N):
    return N[1], N[0]
def povtirz(N):
    return N[1], N[1]-N[0]
def poperirz(N):
    return N[0], N[1]-N[0]
K=sorted(N, key=poperirz)
L=sorted(N, key=povtirz)
M=sorted(N)
N.sort(key=povt)
def podsch(N):
    t=0
    c1=0
    flag = True
    while flag:
        flag = False
        c2=0
        for i in range(len(N)):
            if i-c2 > len(N)-1: break
            if t+N[i-c2][0] <= N[i-c2][1]:
                t+=N[i-c2][0]
                N.pop(i-c2)
                c2+=1
                flag = True
        c1+=c2
    return c1
print(max(podsch(N), podsch(M), podsch(L), podsch(K)))
# Out:
# [[893, 985], [825, 1025], [275, 1133], [31, 1198], [500, 1854], [978, 2201], [955, 2320]]
# [[31, 1198], [275, 1133], [500, 1854], [825, 1025], [893, 985], [955, 2320], [978, 2201]]
# задача [893, 985]
# начальное время 0
# начальный счетчик 0
# конечное время 893
# конечный счетчик 1
# задача [825, 1025]
# начальное время 893
# начальный счетчик 1
# конечное время 893
# конечный счетчик 1
# задача [275, 1133]
# начальное время 893
# начальный счетчик 1
# конечное время 893
# конечный счетчик 1
# задача [31, 1198]
# начальное время 893
# начальный счетчик 1
# конечное время 924
# конечный счетчик 2
# задача [500, 1854]
# начальное время 924
# начальный счетчик 2
# конечное время 1424
# конечный счетчик 3
# задача [978, 2201]
# начальное время 1424
# начальный счетчик 3
# конечное время 1424
# конечный счетчик 3
# задача [955, 2320]
# начальное время 1424
# начальный счетчик 3
# конечное время 1424
# конечный счетчик 3
# задача [31, 1198]
# начальное время 0
# начальный счетчик 0
# конечное время 31
# конечный счетчик 1
# задача [275, 1133]
# начальное время 31
# начальный счетчик 1
# конечное время 306
# конечный счетчик 2
# задача [500, 1854]
# начальное время 306
# начальный счетчик 2
# конечное время 806
# конечный счетчик 3
# задача [825, 1025]
# начальное время 806
# начальный счетчик 3
# конечное время 806
# конечный счетчик 3
# задача [893, 985]
# начальное время 806
# начальный счетчик 3
# конечное время 806
# конечный счетчик 3
# задача [955, 2320]
# начальное время 806
# начальный счетчик 3
# конечное время 1761
# конечный счетчик 4
# задача [978, 2201]
# начальное время 1761
# начальный счетчик 4
# конечное время 1761
# конечный счетчик 4
# 4

# %% [markdown]
# Задача E

# %%
def metod(A):
    return -len(A), A[0]
N = list(input().split())
M={}
for i in N:
    n = str(sorted(i))
    if not n in M.keys():
        M.update({n:[i]})
    else: M[n].append(i)
L=list(map(sorted, list(M.values())))
L.sort(key=metod)
for i in L:
    for j in i:
        print(j, end=' ')

# %% [markdown]
# Задача F

# %%
Data = list(map(int, input().split()))

def mediana(data):
   a=len(data)
   if a%2==0:
      print((data[a//2]+data[a//2-1]-1)//2+1, end=' ')
   else: print(data[a//2], end=' ')

data=[]
for i in Data:
   if not data:
      data.append(i)
   else:
      for j in range(len(data)):
         if data[j] < i:
            data.insert(j, i)
            break
      else: data.append(i)
   mediana(data)
# Out:
# 6 5 3 5 5

# %%
import heapq as hq
Data = list(map(int, input().split()))
def heapsort(N):
    return [hq.heappop(N) for i in range(len(N))]

def mediana(data):
   a=len(data)
   if a%2==0:
      print((data[a//2]+data[a//2-1]-1)//2+1, end=' ')
   else: print(data[a//2], end=' ')
data=[]
for i in Data:
    hq.heappush(data, i)
    data=heapsort(data)
    mediana(data)
# Out:
# 5 15 1 3

# %%
import heapq as hq
Data = list(map(int, input().split()))
def mediana(data):
    mem=[]
    a=len(data)
    if a%2==0:
        for i in range(a//2-1):
            mem.append(hq.heappop(data))
        mem1=hq.heappop(data)
        mem.append(mem1)
        print((mem1+data[0]+1)//2, end=' ')
    else:
        for i in range(a//2):
            mem.append(hq.heappop(data))
        print(data[0], end=' ')
    mem+=data
    return mem
data=[]
for i in Data:
    hq.heappush(data, i)
    data=mediana(data)
# Out:
# 5 10 5 4

# %%
import heapq as hq
import copy
Data = list(map(int, input().split()))
def mediana(N):
    data=copy.deepcopy(N)
    a=len(data)
    if a%2==0:
        for i in range(a//2-1):
            hq.heappop(data)
        print(-((hq.heappop(data)+data[0])//2), end=' ')
    else:
        for i in range(a//2):
            hq.heappop(data)
        print(data[0], end=' ')
data=[]
for i in Data:
    hq.heappush(data, -i)
    mediana(data)
# Out:
# -5 10 -5 4

# %%
import heapq as hq
N = list(map(int, input().split()))
hq.heapify(N)
print(N)
for i in range(len(N)):
    print(hq.heappop(N))
    print(N)
# Out:
# [1, 7, 3, 15, 8, 9, 6, 18, 25, 20, 21, 16, 23, 13, 24]
# 1
# [3, 7, 6, 15, 8, 9, 13, 18, 25, 20, 21, 16, 23, 24]
# 3
# [6, 7, 9, 15, 8, 16, 13, 18, 25, 20, 21, 24, 23]
# 6
# [7, 8, 9, 15, 20, 16, 13, 18, 25, 23, 21, 24]
# 7
# [8, 15, 9, 18, 20, 16, 13, 24, 25, 23, 21]
# 8
# [9, 15, 13, 18, 20, 16, 21, 24, 25, 23]
# 9
# [13, 15, 16, 18, 20, 23, 21, 24, 25]
# 13
# [15, 18, 16, 24, 20, 23, 21, 25]
# 15
# [16, 18, 21, 24, 20, 23, 25]
# 16
# [18, 20, 21, 24, 25, 23]
# 18
# [20, 23, 21, 24, 25]
# 20
# [21, 23, 25, 24]
# 21
# [23, 24, 25]
# 23
# [24, 25]
# 24
# [25]
# 25
# []

# %% [markdown]
# Задача G
