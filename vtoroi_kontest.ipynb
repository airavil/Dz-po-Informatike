# %% [markdown]
# Задача A

# %%
a=input()
def func(a):
    stc=[]
    otk=['(','[','{']
    zak=[')',']','}']
    for i in range(len(a)):
        if a[i] in otk:
            stc.append(a[i])
            if i == len(a)-1:
                return 'No'
        else:
            if stc==[]:
                return 'No'
            else:
                if stc[-1]==otk[zak.index(a[i])]:
                    stc.pop()
                else: return 'No'
    return 'Yes'
print(func(a))
# Out:
# No

# %% [markdown]
# Задача B

# %%
n=int(input())
N=[list(map(int, input().split())) for i in range(n)]
def povt(N):
    return N[1]
N.sort(key=povt)
last = N[0][1]
ans = 1
for l, r in N:
    if l > last:
        ans += 1
        last = r
print(ans)
# Out:
# 1

# %% [markdown]
# Задача C

# %%
def mera(A):
    c=0
    n=len(A)
    for i in range(n-1):
        for j in range(i+1, n):
            if A[i] > A[j]: c+=1
    return c
def sortirovka():
    n, m = map(int, input().split())
    M=[input() for i in range(m)]
    M.sort(key=mera)
    for i in M:
        print(i)
K=int(input())
for i in range(K):
    sortirovka()
    print()
# Out:
# AACATGAAGG
# TTTTGGCCAA
# TTTGGCCAAA
# GATCAGATTT
# CCCGGGGGGA
# ATCGATGCAT

# %% [markdown]
# Задача D

# %%
n=int(input())
N=[list(map(int, input().split())) for i in range(n)]

# %% [markdown]
# Задача E

# %% [markdown]
# Задача F

# %%
Data = list(map(int, input().split()))

def mediana(data):
   a=len(data)
   if a%2==0:
      print((data[a//2]+data[a//2-1]-1)//2+1, end=' ')
   else: print(data[a//2], end=' ')

data=[]
for i in Data:
   if not data:
      data.append(i)
   else:
      for j in range(len(data)):
         if data[j] < i:
            data.insert(j, i)
            break
      else: data.append(i)
   mediana(data)
# Out:
# 6 5 3 5 5

# %% [markdown]
# Задача G
